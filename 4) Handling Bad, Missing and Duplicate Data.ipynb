# %% [markdown]
# # 4 Handling Bad, Missing and Duplicate Data

# %% [markdown]
# # - Cleaning Data:
#     - What is bad data?
#     - define your goal
#     - drop, fill or replace

# %% [markdown]
# ## 4.1Strip white space

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\projects\pluralsight\collection\Cleaning Data Python Data Playbook\artwork_data.csv', low_memory=False)
df_copy = df

# %%
df.loc[df.title.str.contains('\s', regex=True)]
# Out:
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %%
df.title.str.strip()#white space striping on the entired series
# Out:
# 0        A Figure Bowing before a Seated Old Man with h...
# 1        Two Drawings of Frightened Figures, Probably f...
# 2        The Preaching of Warning. Verso: An Old Man En...
# 3           Six Drawings of Figures with Outstretched Arms
# 4        The Circle of the Lustful: Francesca da Rimini...
#                                ...
# 69196                          Larvae (from Tampax Romana)
# 69197                     Living Womb (from Tampax Romana)
# 69198                                        Present Tense
# 69199            Work No. 227: The lights going on and off
# 69200                     Dancing Scene in the West Indies
# Name: title, Length: 69201, dtype: object

# %%
df.title = df.title.str.strip()

# %%
df.loc[df.title.str.contains('\s$', regex=True)]
# Out:
# Empty DataFrame
# Columns: [id, accession_number, artist, artistRole, artistId, title, dateText, medium, creditLine, year, acquisitionYear, dimensions, width, height, depth, units, inscription, thumbnailCopyright, thumbnailUrl, url]
# Index: []

# %%
df.title.transform(lambda x: x.strip())#more flexibility
# Out:
# 0        A Figure Bowing before a Seated Old Man with h...
# 1        Two Drawings of Frightened Figures, Probably f...
# 2        The Preaching of Warning. Verso: An Old Man En...
# 3           Six Drawings of Figures with Outstretched Arms
# 4        The Circle of the Lustful: Francesca da Rimini...
#                                ...
# 69196                          Larvae (from Tampax Romana)
# 69197                     Living Womb (from Tampax Romana)
# 69198                                        Present Tense
# 69199            Work No. 227: The lights going on and off
# 69200                     Dancing Scene in the West Indies
# Name: title, Length: 69201, dtype: object

# %% [markdown]
# ## 4.2 Replace bad data

# %%
df.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
pd.isna(df.loc[:,'dateText'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 69196    False
# 69197    False
# 69198    False
# 69199    False
# 69200    False
# Name: dateText, Length: 69201, dtype: bool

# %%
from numpy import nan

# %%
df.replace({'dateText' : {'date not known': nan}})
# Out:
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %%
df.replace({'dateText' : {'date not known': nan}}, inplace=True)

# %%
df = pd.read_csv(r'C:\projects\pluralsight\collection\artwork_data.csv')

# %%
df.head(2)
# Out:
#      id accession_number         artist artistRole  artistId  \
# 0  1035           A00001  Blake, Robert     artist        38
# 1  1036           A00002  Blake, Robert     artist        38
#
#                                                title        dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
#
#                             creditLine year  acquisitionYear  \
# 0  Presented by Mrs John Richmond 1922  NaN           1922.0
# 1  Presented by Mrs John Richmond 1922  NaN           1922.0
#
#               dimensions width height  depth units inscription  \
# 0  support: 394 x 419 mm   394    419    NaN    mm         NaN
# 1  support: 311 x 213 mm   311    213    NaN    mm         NaN
#
# ...

# %%
df.loc[df.dateText == 'date not known', ['dateText']]=nan
df.head(2)
# Out:
#      id accession_number         artist artistRole  artistId  \
# 0  1035           A00001  Blake, Robert     artist        38
# 1  1036           A00002  Blake, Robert     artist        38
#
#                                                title dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...      NaN
# 1  Two Drawings of Frightened Figures, Probably f...      NaN
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
#
#                             creditLine year  acquisitionYear  \
# 0  Presented by Mrs John Richmond 1922  NaN           1922.0
# 1  Presented by Mrs John Richmond 1922  NaN           1922.0
#
#               dimensions width height  depth units inscription  \
# 0  support: 394 x 419 mm   394    419    NaN    mm         NaN
# 1  support: 311 x 213 mm   311    213    NaN    mm         NaN
#
# ...

# %%
a = df.loc[df.year.notnull() & df.year.astype(str).str.contains('[^0-9]')]
a
# Out:
#            id accession_number            artist artistRole  artistId  \
# 2        1037           A00003     Blake, Robert     artist        38
# 4        1039           A00005    Blake, William     artist        39
# 5        1040           A00006    Blake, William     artist        39
# 6        1041           A00007    Blake, William     artist        39
# 7        1042           A00008    Blake, William     artist        39
# ...       ...              ...               ...        ...       ...
# 68072   99456           T12733  Roberts, William     artist      1855
# 68074   99458           T12735  Roberts, William     artist      1855
# 68076   99460           T12737  Roberts, William     artist      1855
# 68077   99462           T12738  Roberts, William     artist      1855
# 69165  121190           T13834  Barlow, Phyllida     artist     10908
#
#                                                    title  \
# 2      The Preaching of Warning. Verso: An Old Man En...
# ...

# %% [markdown]
# ## 4.3 Fill missing data

# %%
df = df_copy

# %%
df.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
df.fillna(value= {'depth':0})
# Out:
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %%
df.fillna(value= {'depth':0}, inplace=True)

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [id, accession_number, artist, artistRole, artistId, title, dateText, medium, creditLine, year, acquisitionYear, dimensions, width, height, depth, units, inscription, thumbnailCopyright, thumbnailUrl, url]
# Index: []

# %% [markdown]
# ## 4.4 Drop bad data

# %%
df=df_copy

# %%
df.shape
# Out:
# (69201, 20)

# %%
df.dropna()
# Out:
#           id accession_number             artist artistRole  artistId  \
# 1025     550           A01029  Ardizzone, Edward     artist       659
# 1026     551           A01030  Ardizzone, Edward     artist       659
# 1027     552           A01031  Ardizzone, Edward     artist       659
# 1028     553           A01032  Ardizzone, Edward     artist       659
# 1029     554           A01033  Ardizzone, Edward     artist       659
# ...      ...              ...                ...        ...       ...
# 67576  89914           T12231       Moon, Jeremy     artist      1656
# 67577  89915           T12232       Moon, Jeremy     artist      1656
# 67578  89916           T12233       Moon, Jeremy     artist      1656
# 67579  89917           T12234       Moon, Jeremy     artist      1656
# 67580  89918           T12235       Moon, Jeremy     artist      1656
#
#                     title dateText                        medium  \
# ...

# %%
df.dropna().shape#=df.dropna(how='any')
# Out:
# (3846, 20)

# %%
df.dropna(how='all').shape
# Out:
# (69201, 20)

# %%
df.dropna(thresh=15).shape#number of value nan
# Out:
# (66571, 20)

# %%
df.dropna(subset=['year','acquisitionYear']).shape
# Out:
# (63781, 20)

# %%
df.dropna(subset=['year','acquisitionYear'],how='all').shape
# Out:
# (69198, 20)

# %%
df.dropna(subset=['year','acquisitionYear'], inplace=True)

# %% [markdown]
# ## 4.5 Identify & Drop Duplicate data

# %%
df = df_copy

# %%
df
# Out:
#            id accession_number              artist artistRole  artistId  \
# 2        1037           A00003       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# 5        1040           A00006      Blake, William     artist        39
# 6        1041           A00007      Blake, William     artist        39
# 7        1042           A00008      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %% [markdown]
# - dilling with duplicates rows

# %%
df.drop_duplicates()
# Out:
#            id accession_number              artist artistRole  artistId  \
# 2        1037           A00003       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# 5        1040           A00006      Blake, William     artist        39
# 6        1041           A00007      Blake, William     artist        39
# 7        1042           A00008      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %%
df.drop_duplicates(subset='artist')#ideal to do a groupy by with conserving structure
# Out:
#            id accession_number                             artist  \
# 2        1037           A00003                      Blake, Robert
# 4        1039           A00005                     Blake, William
# 49       1183           A00050                   Richmond, George
# 56       1695           A00057  Burne-Jones, Sir Edward Coley, Bt
# 130      1915           A00131                    Callow, William
# ...       ...              ...                                ...
# 69188  121283           T13857                        Rhodes, Lis
# 69190  117863           T13859               Andrade, Jonathas de
# 69192  123620           T13861                      Sterne, Hedda
# 69194  122958           T13863                 P-Orridge, Genesis
# 69200  127035           T13869                  Brunias, Agostino
#
#           artistRole  artistId  \
# 2             artist        38
# 4             artist        39
# 49     attributed to       447
# 56            artist        68
# ...

# %%
df.drop_duplicates(subset='artist', keep='first')
# Out:
#            id accession_number                             artist  \
# 2        1037           A00003                      Blake, Robert
# 4        1039           A00005                     Blake, William
# 49       1183           A00050                   Richmond, George
# 56       1695           A00057  Burne-Jones, Sir Edward Coley, Bt
# 130      1915           A00131                    Callow, William
# ...       ...              ...                                ...
# 69188  121283           T13857                        Rhodes, Lis
# 69190  117863           T13859               Andrade, Jonathas de
# 69192  123620           T13861                      Sterne, Hedda
# 69194  122958           T13863                 P-Orridge, Genesis
# 69200  127035           T13869                  Brunias, Agostino
#
#           artistRole  artistId  \
# 2             artist        38
# 4             artist        39
# 49     attributed to       447
# 56            artist        68
# ...

# %%
df.drop_duplicates(subset='artist', keep='last')
# Out:
#            id accession_number                      artist artistRole  \
# 2        1037           A00003               Blake, Robert     artist
# 837     12751           A00841      Rooke, Thomas Matthews     artist
# 859     13491           A00863              Smirke, Robert     artist
# 861     13617           A00865  Smith, Sidney Robert James     artist
# 904     14415           A00908             Townroe, Reuben     artist
# ...       ...              ...                         ...        ...
# 69193  122900           T13862             Flanagan, Barry     artist
# 69197  122961           T13866          P-Orridge, Genesis     artist
# 69198  121181           T13867                Hatoum, Mona     artist
# 69199  112306           T13868               Creed, Martin     artist
# 69200  127035           T13869           Brunias, Agostino     artist
#
#        artistId                                              title  \
# ...

# %%
df.drop_duplicates(subset='artist', keep=False)
# Out:
#            id accession_number  \
# 2        1037           A00003
# 1822    98332          AR00085
# 40581   11567           N00183
# 40634    6891           N00349
# 40657     491           N00373
# ...       ...              ...
# 69181  115217           T13850
# 69188  121283           T13857
# 69190  117863           T13859
# 69192  123620           T13861
# 69200  127035           T13869
#
#                                                   artist artistRole  artistId  \
# 2                                          Blake, Robert     artist        38
# 1822                                   Grimonprez, Johan     artist      9716
# 40581                                   Phillips, Thomas     artist       423
# 40634                                      Howard, Henry     artist       279
# 40657                                 Allan, Sir William     artist         4
# ...                                                  ...        ...       ...
# ...

# %%
df.duplicated()
# Out:
# 2        False
# 4        False
# 5        False
# 6        False
# 7        False
#          ...
# 69196    False
# 69197    False
# 69198    False
# 69199    False
# 69200    False
# Length: 63781, dtype: bool

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, accession_number, artist, artistRole, artistId, title, dateText, medium, creditLine, year, acquisitionYear, dimensions, width, height, depth, units, inscription, thumbnailCopyright, thumbnailUrl, url]
# Index: []

# %%
df.duplicated(subset=['artist', 'title'], keep=False)
# Out:
# 2        False
# 4         True
# 5         True
# 6         True
# 7         True
#          ...
# 69196    False
# 69197    False
# 69198    False
# 69199    False
# 69200    False
# Length: 63781, dtype: bool

# %%
df.loc[df.duplicated(subset=['artist', 'title'], keep=False)]
# Out:
#            id accession_number            artist artistRole  artistId  \
# 4        1039           A00005    Blake, William     artist        39
# 5        1040           A00006    Blake, William     artist        39
# 6        1041           A00007    Blake, William     artist        39
# 7        1042           A00008    Blake, William     artist        39
# 8        1043           A00009    Blake, William     artist        39
# ...       ...              ...               ...        ...       ...
# 69169  121194           T13838  Barlow, Phyllida     artist     10908
# 69170  121195           T13839  Barlow, Phyllida     artist     10908
# 69171  121196           T13840  Barlow, Phyllida     artist     10908
# 69172  121197           T13841  Barlow, Phyllida     artist     10908
# 69173  121198           T13842  Barlow, Phyllida     artist     10908
#
#                                                    title  \
# 4      The Circle of the Lustful: Francesca da Rimini...
# ...

# %%
df.loc[df.title.str.contains('The Circle of the Lustful')]
# Out:
#          id accession_number          artist artistRole  artistId  \
# 4      1039           A00005  Blake, William     artist        39
# 57394  1156           T01950  Blake, William     artist        39
#
#                                                    title  \
# 4      The Circle of the Lustful: Francesca da Rimini...
# 57394  The Circle of the Lustful: Francesca da Rimini...
#
#                      dateText                   medium  \
# 4      1826–7, reprinted 1892  Line engraving on paper
# 57394  1826–7, reprinted 1968  Line-engraving on paper
#
#                                               creditLine  year  \
# 4      Purchased with the assistance of a special gra...  1826
# 57394             Presented by Lessing J. Rosenwald 1975  1826
#
#        acquisitionYear           dimensions width height  depth units  \
# 4               1919.0  image: 243 x 335 mm   243    335    0.0    mm
# 57394           1975.0  image: 243 x 335 mm   243    335    0.0    mm
#
# ...

# %%
df.loc[df.title.str.contains('The Circle of the Lustful')]
