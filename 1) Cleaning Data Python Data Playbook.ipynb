# %% [markdown]
# # 1.Cleaning Data: Python Data Playbook

# %% [markdown]
# ## Understanding Your Data

# %% [markdown]
# - understand and convert types
# - aggregate data
# - normalize data
# - transform data
# - filter data

# %% [markdown]
# ## 1.1 Understanding and converting your data

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:/projects/pluralsight/collection/Cleaning Data Python Data Playbook/artwork_data.csv')
# Out:
# c:\program files\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (9,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
df.dtypes
# Out:
# id                      int64
# accession_number       object
# artist                 object
# artistRole             object
# artistId                int64
# title                  object
# dateText               object
# medium                 object
# creditLine             object
# year                   object
# acquisitionYear       float64
# dimensions             object
# width                  object
# height                 object
# depth                 float64
# units                  object
# inscription            object
# thumbnailCopyright     object
# thumbnailUrl           object
# url                    object
# dtype: object

# %%
df.columns
# Out:
# Index(['id', 'accession_number', 'artist', 'artistRole', 'artistId', 'title',
#        'dateText', 'medium', 'creditLine', 'year', 'acquisitionYear',
#        'dimensions', 'width', 'height', 'depth', 'units', 'inscription',
#        'thumbnailCopyright', 'thumbnailUrl', 'url'],
#       dtype='object')

# %%
df.acquisitionYear
# Out:
# 0        1922.0
# 1        1922.0
# 2        1922.0
# 3        1922.0
# 4        1919.0
#           ...
# 69196    2013.0
# 69197    2013.0
# 69198    2013.0
# 69199    2013.0
# 69200    2013.0
# Name: acquisitionYear, Length: 69201, dtype: float64

# %%
df.acquisitionYear.astype(float)
# Out:
# 0        1922.0
# 1        1922.0
# 2        1922.0
# 3        1922.0
# 4        1919.0
#           ...
# 69196    2013.0
# 69197    2013.0
# 69198    2013.0
# 69199    2013.0
# 69200    2013.0
# Name: acquisitionYear, Length: 69201, dtype: float64

# %%
df.acquisitionYear=df.acquisitionYear.astype(float)

# %%
df.acquisitionYear.dtype
# Out:
# dtype('float64')

# %%
fulldf = pd.read_csv(r'C:/projects/pluralsight/collection/Cleaning Data Python Data Playbook/artwork_data.csv', low_memory=False)

# %%
fulldf.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
fulldf.dtypes
# Out:
# id                      int64
# accession_number       object
# artist                 object
# artistRole             object
# artistId                int64
# title                  object
# dateText               object
# medium                 object
# creditLine             object
# year                   object
# acquisitionYear       float64
# dimensions             object
# width                  object
# height                 object
# depth                 float64
# units                  object
# inscription            object
# thumbnailCopyright     object
# thumbnailUrl           object
# url                    object
# dtype: object

# %%
fulldf.height.astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-99c9ee63bec2> in <module>
# ----> 1 fulldf.height.astype(float)
#
# c:\program files\python38\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5695         else:
#    5696             # else, only a single dtype is given
# -> 5697             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5698             return self._constructor(new_data).__finalize__(self)
#    5699
#
# c:\program files\python38\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...

# %%
pd.to_numeric(fulldf.height, errors='coerce')
# Out:
# 0         419.0
# 1         213.0
# 2         467.0
# 3         394.0
# 4         335.0
#           ...
# 69196     305.0
# 69197     305.0
# 69198    2410.0
# 69199       NaN
# 69200     660.0
# Name: height, Length: 69201, dtype: float64

# %%
fulldf.height = pd.to_numeric(fulldf.height, errors='coerce')

# %%
df.height = pd.to_numeric(df.height,errors='coerce')

# %% [markdown]
# ## 1.2 Aggregating Data

# %%
df.year = pd.to_numeric(df.year, errors='coerce')
df.year
# Out:
# 0           NaN
# 1           NaN
# 2        1785.0
# 3           NaN
# 4        1826.0
#           ...
# 69196    1975.0
# 69197    1976.0
# 69198    1996.0
# 69199    2000.0
# 69200    1764.0
# Name: year, Length: 69201, dtype: float64

# %%
df.year.max()
# Out:
# 2012.0

# %%
df.year.min()
# Out:
# 1545.0

# %%
df.year.sum()
# Out:
# 119136604.0

# %%
df.year.mean()
# Out:
# 1867.2278227070403

# %%
df.year.std()
# Out:
# 72.01271840758226

# %%
df.artist.min()
# Out:
# '?British School'

# %%
df.agg(['min','max','mean','std'])
# Out:
#                  id accession_number             artist artistRole  \
# min        3.000000           A00001    ?British School      after
# max   129068.000000           T13869  Štyrský, Jindrich   style of
# mean   39148.026213              NaN                NaN        NaN
# std    25980.468687              NaN                NaN        NaN
#
#           artistId                                              title  \
# min       0.000000                                             ! 1971
# max   19232.000000  “What is to be done?” 1984. Alternative Techno...
# mean   1201.063251                                                NaN
# std    2019.422535                                                NaN
#
#               dateText         year  acquisitionYear         depth  \
# min               1545  1545.000000      1823.000000      1.000000
# max   published c.1860  2012.000000      2013.000000  18290.000000
# mean               NaN  1867.227823      1910.646856    479.197772
# ...

# %%
df.agg('mean', axis='columns')
# Out:
# Series([], dtype: float64)

# %% [markdown]
# ## Normalize Data

# %%
df.dtypes
# Out:
# id                      int64
# accession_number       object
# artist                 object
# artistRole             object
# artistId                int64
# title                  object
# dateText               object
# medium                 object
# creditLine             object
# year                  float64
# acquisitionYear       float64
# dimensions             object
# width                  object
# height                 object
# depth                 float64
# units                  object
# inscription            object
# thumbnailCopyright     object
# thumbnailUrl           object
# url                    object
# dtype: object

# %%
df.height.min()
# Out:
# 6.0

# %%
df.height.max()
# Out:
# 37500.0

# %%
df.height.mean()
# Out:
# 346.4361727326562

# %%
df.height.std()
# Out:
# 538.037975392532

# %%
height = df.height

# %%
norm = (height - height.mean())/height.std()
norm
# Out:
# 0        0.134867
# 1       -0.248005
# 2        0.224081
# 3        0.088402
# 4       -0.021255
#            ...
# 69196   -0.077013
# 69197   -0.077013
# 69198    3.835350
# 69199         NaN
# 69200    0.582791
# Name: height, Length: 69201, dtype: float64

# %%
minmax = (height - height.min()) / (height.max() - height.min())
minmax
# Out:
# 0        0.011015
# 1        0.005521
# 2        0.012295
# 3        0.010348
# 4        0.008775
#            ...
# 69196    0.007975
# 69197    0.007975
# 69198    0.064117
# 69199         NaN
# 69200    0.017443
# Name: height, Length: 69201, dtype: float64

# %%
minmax.min()
# Out:
# 0.0

# %%
minmax.max()
# Out:
# 1.0

# %%
df['standarized_height'] = norm

# %%
df.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %% [markdown]
# ## 1.3 Transform Data

# %%
df.height.transform(lambda x: print(x))
# Out:
# 419.0
# 213.0
# 467.0
# 394.0
# 335.0
# 338.0
# 334.0
# 340.0
# 335.0
# 340.0
# 340.0
# 150.0
# 151.0
# 153.0
# 152.0
# 152.0
# 153.0
# 153.0
# 150.0
# 152.0
# 152.0
# 152.0
# 151.0
# 151.0
# 150.0
# 151.0
# 150.0
# 151.0
# 150.0
# 150.0
# 151.0
# 149.0
# 389.0
# 166.0
# 97.0
# 97.0
# 79.0
# 64.0
# 64.0
# 450.0
# 343.0
# 203.0
# 425.0
# 450.0
# 338.0
# 276.0
# 339.0
# 370.0
# 425.0
# 157.0
# nan
# nan
# nan
# nan
# nan
# nan
# 184.0
# 222.0
# 171.0
# 216.0
# 179.0
# 225.0
# 180.0
# 179.0
# 235.0
# 222.0
# 152.0
# 165.0
# 165.0
# 149.0
# 149.0
# 518.0
# 518.0
# 398.0
# 400.0
# 400.0
# 400.0
# 131.0
# 241.0
# nan
# nan
# nan
# 153.0
# 178.0
# 157.0
# 133.0
# 143.0
# 175.0
# 190.0
# 127.0
# 335.0
# 140.0
# 133.0
# 148.0
# 264.0
# 152.0
# 140.0
# 162.0
# 166.0
# 154.0
# 117.0
# 149.0
# 142.0
# 146.0
# 185.0
# 130.0
# 178.0
# 304.0
# 303.0
# 225.0
# 84.0
# 74.0
# 75.0
# 73.0
# 73.0
# 73.0
# 73.0
# 72.0
# 74.0
# 77.0
# 75.0
# 77.0
# 75.0
# 76.0
# 76.0
# 75.0
# 77.0
# 98.0
# 216.0
# 235.0
# ...

# %%
df.height.transform(lambda x: x/10)
# Out:
# 0         41.9
# 1         21.3
# 2         46.7
# 3         39.4
# 4         33.5
#          ...
# 69196     30.5
# 69197     30.5
# 69198    241.0
# 69199      NaN
# 69200     66.0
# Name: height, Length: 69201, dtype: float64

# %%
df.groupby('artist').transform('nunique')#count the number of unique values per row and per column group by artist
# Out:
#         id  accession_number  artistRole  artistId  title  dateText  medium  \
# 0        4                 4           1         1      4         2       3
# 1        4                 4           1         1      4         2       3
# 2        4                 4           1         1      4         2       3
# 3        4                 4           1         1      4         2       3
# 4      180               180           2         1    156        56      41
# ...    ...               ...         ...       ...    ...       ...     ...
# 69196    4                 4           1         1      4         2       4
# 69197    4                 4           1         1      4         2       4
# 69198   10                10           1         1     10         9       9
# 69199   13                13           1         1     13         6      10
# 69200    1                 1           1         1      1         1       1
#
# ...

# %%
df.groupby('artist')['height'].transform('mean')
# Out:
# 0        3.732500e+02
# 1        3.732500e+02
# 2        3.732500e+02
# 3        3.732500e+02
# 4       -5.124096e+16
#              ...
# 69196    3.050000e+02
# 69197    3.050000e+02
# 69198   -2.767012e+18
# 69199   -2.837961e+18
# 69200    6.600000e+02
# Name: height, Length: 69201, dtype: float64

# %%
df.artist
# Out:
# 0             Blake, Robert
# 1             Blake, Robert
# 2             Blake, Robert
# 3             Blake, Robert
# 4            Blake, William
#                 ...
# 69196    P-Orridge, Genesis
# 69197    P-Orridge, Genesis
# 69198          Hatoum, Mona
# 69199         Creed, Martin
# 69200     Brunias, Agostino
# Name: artist, Length: 69201, dtype: object

# %% [markdown]
# #### we transformed the data but we didn't integrate it in the df

# %%
df['mean_height_by_artist'] = df.groupby('artist')['height'].transform('mean')

# %%
df
# Out:
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %% [markdown]
# ## 1.4 Filtering Data

# %%
df.filter(items=['id','artist'])
# Out:
#            id              artist
# 0        1035       Blake, Robert
# 1        1036       Blake, Robert
# 2        1037       Blake, Robert
# 3        1038       Blake, Robert
# 4        1039      Blake, William
# ...       ...                 ...
# 69196  122960  P-Orridge, Genesis
# 69197  122961  P-Orridge, Genesis
# 69198  121181        Hatoum, Mona
# 69199  112306       Creed, Martin
# 69200  127035   Brunias, Agostino
#
# [69201 rows x 2 columns]

# %%
df.filter(like='year')
# Out:
#        year
# 0      None
# 1      None
# 2      1785
# 3      None
# 4      1826
# ...     ...
# 69196  1975
# 69197  1976
# 69198  1996
# 69199  2000
# 69200  1764
#
# [69201 rows x 1 columns]

# %%
df.filter(regex='(?i)year')
# Out:
#        year  acquisitionYear
# 0      None           1922.0
# 1      None           1922.0
# 2      1785           1922.0
# 3      None           1922.0
# 4      1826           1919.0
# ...     ...              ...
# 69196  1975           2013.0
# 69197  1976           2013.0
# 69198  1996           2013.0
# 69199  2000           2013.0
# 69200  1764           2013.0
#
# [69201 rows x 2 columns]

# %%
df.filter(axis=0, regex='^100.$')
# Out:
#          id accession_number                          artist artistRole  \
# 1000  14704           A01004  Turner, Joseph Mallord William     artist
# 1001  14705           A01005  Turner, Joseph Mallord William     artist
# 1002  14706           A01006  Turner, Joseph Mallord William     artist
# 1003  14707           A01007  Turner, Joseph Mallord William     artist
# 1004  14708           A01008  Turner, Joseph Mallord William     artist
# 1005  14709           A01009  Turner, Joseph Mallord William     artist
# 1006  14710           A01010  Turner, Joseph Mallord William     artist
# 1007  14711           A01011  Turner, Joseph Mallord William     artist
# 1008  14712           A01012  Turner, Joseph Mallord William     artist
# 1009  14713           A01013  Turner, Joseph Mallord William     artist
#
#       artistId                                              title dateText  \
# 1000       558                               Hedging and Ditching     1812
# ...

# %%
data.filter()
